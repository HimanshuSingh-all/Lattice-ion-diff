# %%
import numpy as np
from datetime import date
np.random.seed()
import glob
from lat2d import PARSER_MSD, latmc
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
write=0
N=20
NSTEPS=15000
wp=100
today=date.today()
epsilon=2223/1300
equilibriation=5000
Ns=NSTEPS-equilibriation

WT=wp

# %%
today=date.today()

coverage=100-np.array([1,3,7,9,11,13,15,17,19,21])# , 30, 40, 50 , 60, 70, 80,90])
for cov in coverage:
    day=today.strftime("%B-%d-%Y")
    fname=f"Coverage-{cov}.txt"
    with open(fname,'w+') as fhand: 
        mylat=latmc.lat_2d(N,cov/100,epsilon)
        mylat.init_lattice()
        mylat.init_energylattice()
        NIONS=len(mylat.ions)
        fhand.write(f"Created:{day} \n")
        fhand.write(f"Coverage:{cov} \n")
        fhand.write(f"N:{N} \n")
        fhand.write(f"NUM-IONS:{NIONS} \n")
        fhand.write(f"NSTEPS:{NSTEPS} \n")
        fhand.write(f"WRITE-PERIODICITY:{wp} \n")
        fhand.write(f"epsilon:{epsilon} \n")
        for i,step in enumerate(range(NSTEPS)):
            mylat.onemcstep()
            if i%WT==0 and i>equilibriation:
                for io in mylat.ions:
                    fhand.write(f"{io.pos[0]}  {io.pos[1]} \n")

# %%
import os
rename_list = glob.glob('*.txt')
for i,fname in enumerate(rename_list):
    os.rename(fname,r'data:{i}.txt')
rename_list = glob.glob('*.txt')
rename_list
# Out:
# []

# %%
MSDS_=dict()
paramlen=7
steps=np.arange(0*100,(Ns//4),wp)

#print(i,'\n',names)
for fname in glob.glob('*.txt'):
    print(fname)
    params=PARSER_MSD.getrunparams(fname,paramlen)
    narray=PARSER_MSD.getnparray(fname,params,paramlen)
    MSDS_[int(float(params['Coverage'].split()[0]))]=np.array(PARSER_MSD.time_msd(narray,fname,paramlen))

MSDS_
# Out:
# Coverage-95.txt
# 25
# _______________________
# 95
#  Coverage-95.txt
# Coverage-96.txt
# 25
# _______________________
# 96
#  Coverage-96.txt
# Coverage-82.txt
# 25
# _______________________
# 82
#  Coverage-82.txt
# Coverage-84.txt
# 25
# _______________________
# 84
#  Coverage-84.txt
# Coverage-80.txt
# 25
# _______________________
# 80
#  Coverage-80.txt
# Coverage-92.txt
# 25
# _______________________
# 92
#  Coverage-92.txt
# Coverage-85.txt
# 25
# _______________________
# 85
#  Coverage-85.txt
# Coverage-86.txt
# 25
# _______________________
# 86
#  Coverage-86.txt
# Coverage-98.txt
# 25
# _______________________
# 98
#  Coverage-98.txt
# Coverage-90.txt
# 25
# _______________________
# 90
#  Coverage-90.txt
# Coverage-88.txt
# 25
# _______________________
# 88
#  Coverage-88.txt
# Coverage-94.txt
#          9.11700921,  9.64576758, 10.16706609, 10.69926471, 11.23023083,
#         11.75825792, 12.27673797, 12.79462074, 13.31133333, 13.83744038]),
#  86: array([0.50145349, 0.8782666 , 1.22734981, 1.56762546, 1.89686418,
#         2.2225869 , 2.54376264, 2.86468183, 3.18171835, 3.49261824,
#         3.79704017, 4.1005413 , 4.3996755 , 4.70246238, 5.00034607,
#         5.29801765, 5.58327425, 5.87119581, 6.15297965, 6.4413821 ,
#         6.72827221, 7.02200997, 7.31793146, 7.61302326, 7.91043369]),
#  98: array([0.04885985, 0.08565643, 0.12000425, 0.15378625, 0.18592597,
#         0.2171659 , 0.24761535, 0.27654743, 0.30617914, 0.33415501,
#         0.36209995, 0.39089256, 0.41896061, 0.44630852, 0.47455053,
#         0.50282764, 0.53011448, 0.55662635, 0.58325893, 0.60859597,
#         0.63363422, 0.65905778, 0.68357277, 0.70758503, 0.73200496]),
#  90: array([0.45793651, 0.80973654, 1.1375    , 1.46081871, 1.77875296,
#         2.09540024, 2.41240942, 2.72857143, 3.04796296, 3.36470037,
#         3.678125  , 3.99157088, 4.30507106, 4.61552288, 4.9151455 ,
#         5.21837349, 5.51839431, 5.80764746, 6.1009375 , 6.38987342,
#         6.67581909, 6.96255411, 7.2497807 , 7.53633333, 7.82331081]),
#  88: array([0.52278525, 0.92475984, 1.30746922, 1.66444378, 2.02299927,
#         2.39073192, 2.7576581 , 3.12059815, 3.48522727, 3.83414198,
#         4.18995351, 4.54571578, 4.89564614, 5.24883021, 5.60528274,
#         5.96430038, 6.3168653 , 6.66656145, 7.01725852, 7.36719649,
#         7.72013403, 8.0806523 , 8.43839713, 8.79041667, 9.13962684]),
#  94: array([0.18326531, 0.31714089, 0.44475   , 0.56404211, 0.68130496,
#         0.79948387, 0.91391304, 1.02789744, 1.14577778, 1.25474157,
#         1.36233333, 1.46832184, 1.57575194, 1.68207059, 1.7855873 ,
#         1.8871004 , 1.98826016, 2.08767078, 2.18486667, 2.28165401,
#         2.37736752, 2.47445887, 2.56950877, 2.66428444, 2.76317117])}

# %%
for cov in coverage:
    value=MSDS_[cov]
    plt.plot(steps,value,label=f'Coverage:{cov}'.split()[0],linestyle='--',marker='>')
    
plt.xlabel(r'Time Step $\to$')
plt.title('MSD(Time Origin) vs Time Step')
plt.ylabel(r'MSD $\to$')
plt.legend()
plt.grid()
plt.show()

# %%
D  = []
x = np.arange(0,(NSTEPS-equilibriation)//4,100)
for cov in coverage:
    D.append(stats.linregress(x,MSDS_[cov]).slope/4)

# %%
plt.plot(100-coverage,D)
